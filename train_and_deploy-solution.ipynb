# %% [markdown]
# <h1>C4 Solution</h1>

# %% [markdown]
# <h3>Install and import</h3>

# %%
# %%capture
import sys
# !{sys.executable} -m pip install smdebug torch torchvision tqdm

# %%
import os
import boto3
import sagemaker
from sagemaker.tuner import CategoricalParameter, ContinuousParameter, HyperparameterTuner
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role
from sagemaker.debugger import Rule, DebuggerHookConfig, TensorBoardOutputConfig, CollectionConfig, ProfilerRule, rule_configs, ProfilerConfig, FrameworkProfile
from sagemaker.analytics import HyperparameterTuningJobAnalytics

# %% [markdown]
# <h3>Get the data and copy it to S3</h3>

# %%
# %%capture
# !wget https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip
# !unzip dogImages.zip

# %%
# %%capture
# !aws s3 cp dogImages s3://udacitymlproject4/ --recursive

# %% [markdown]
# <h3>Set up parameters, estimator, and tuner</h3>

# %%
hyperparameter_ranges = {
    "learning_rate": ContinuousParameter(0.001, 0.1),
    "batch_size": CategoricalParameter([32, 64, 128, 256, 512]),
}

role = sagemaker.get_execution_role()

objective_metric_name = "Test Loss"
objective_type = "Minimize"
metric_definitions = [{"Name": "Test Loss", "Regex": "Testing Loss: ([0-9\\.]+)"}]

# %%
estimator = PyTorch(
    entry_point="hpo.py",
    base_job_name='pytorch_dog_hpo',
    role=role,
    framework_version="1.4.0",
    instance_count=1,
    instance_type="ml.g4dn.xlarge",
    py_version='py3'
)

tuner = HyperparameterTuner(
    estimator,
    objective_metric_name,
    hyperparameter_ranges,
    metric_definitions,
    max_jobs=2,
    max_parallel_jobs=1,  # you once have one ml.g4dn.xlarge instance available
    objective_type=objective_type
)

# %% [markdown]
# <h3>Fit the tuner</h3>

# %%
os.environ['SM_CHANNEL_TRAINING']='s3://udacitymlproject4/'
os.environ['SM_MODEL_DIR']='s3://udacitymlproject4/model/'
os.environ['SM_OUTPUT_DATA_DIR']='s3://udacitymlproject4/output/'
tuner.fit({"training": "s3://udacitymlproject4/"})
# Out:
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# ...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................!

# %% [markdown]
# <h3>Describe the tuning results</h3>

# %%
exp = HyperparameterTuningJobAnalytics(
  hyperparameter_tuning_job_name='pytorch-training-230417-1019')

jobs = exp.dataframe()

jobs.sort_values('FinalObjectiveValue', ascending=0)
# Out:
#   batch_size  learning_rate                            TrainingJobName  \
# 2      "256"       0.015983  pytorch-training-230417-1019-001-1a225b0d
# 0      "128"       0.006621  pytorch-training-230417-1019-003-2e416da5
# 1      "512"       0.009014  pytorch-training-230417-1019-002-ba9c7841
#
#   TrainingJobStatus  FinalObjectiveValue         TrainingStartTime  \
# 2         Completed                988.0 2023-04-17 10:20:38+00:00
# 0         Completed                220.0 2023-04-17 10:46:45+00:00
# 1            Failed                  NaN 2023-04-17 10:44:03+00:00
#
#             TrainingEndTime  TrainingElapsedTimeSeconds
# 2 2023-04-17 10:41:20+00:00                      1242.0
# 0 2023-04-17 11:05:51+00:00                      1146.0
# 1 2023-04-17 10:46:31+00:00                       148.0

# %% [markdown]
# ## Imp: If kernel dies, how to continue from a completed training job

# %%
BetterTrainingJobName='dog-pytorch-2023-04-17-11-29-15-852'
my_estimator = sagemaker.estimator.Estimator.attach(BetterTrainingJobName)
my_estimator.hyperparameters()
best_estimator=my_estimator
# Out:
# 2023-04-17 11:44:55 Starting - Preparing the instances for training
# 2023-04-17 11:44:55 Downloading - Downloading input data
# 2023-04-17 11:44:55 Training - Training image download completed. Training in progress.
# 2023-04-17 11:44:55 Uploading - Uploading generated training model
# 2023-04-17 11:44:55 Completed - Training job completed

# %% [markdown]
# <h3>Prepare to perform Training on Best Estimator</h3>

# %%
best_estimator=tuner.best_estimator()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 best_estimator=tuner.best_estimator()
#
# NameError: name 'tuner' is not defined

# %%
best_estimator.hyperparameters()
# Out:
# {'batch_size': '128',
#  'learning_rate': '"0.00662117582001255"',
#  'sagemaker_container_log_level': '20',
#  'sagemaker_job_name': '"dog-pytorch-2023-04-17-11-29-15-852"',
#  'sagemaker_program': '"hpo.py"',
#  'sagemaker_region': '"us-east-1"',
#  'sagemaker_submit_directory': '"s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz"'}

# %%
hyperparameters = {"batch_size": int(best_estimator.hyperparameters()['batch_size'].replace('"', '')), \
                   "learning_rate": best_estimator.hyperparameters()['learning_rate']}
hyperparameters
# Out:
# {'batch_size': 128, 'learning_rate': '0.00662117582001255'}

# %%
rules = [
    Rule.sagemaker(rule_configs.vanishing_gradient()),
    Rule.sagemaker(rule_configs.overfit()),
    Rule.sagemaker(rule_configs.overtraining()),
    Rule.sagemaker(rule_configs.poor_weight_initialization()),
    ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
]

# %%
hook_config = DebuggerHookConfig(
    hook_parameters={
        "train.save_interval": "1",
        "eval.save_interval": "1"
    }
)

profiler_config = ProfilerConfig(
    system_monitor_interval_millis=500, framework_profile_params=FrameworkProfile(num_steps=1)
)

# %% [markdown]
# <h2>Creating an Estimator</h2>

# %%
#adjust this cell to accomplish multi-instance training
estimator = PyTorch(
    entry_point='hpo.py',
    base_job_name='dog-pytorch',
    role=role,
    instance_count=1,
    instance_type='ml.m5.xlarge',
    framework_version='1.4.0',
    py_version='py3',
    hyperparameters=hyperparameters,
    ## Debugger and Profiler parameters
    rules = rules,
    debugger_hook_config=hook_config,
    profiler_config=profiler_config,
)
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
estimator.fit({"training": "s3://udacitymlproject4/"}, wait=False)
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: dog-pytorch-2023-04-17-11-26-09-752

# %% [markdown]
# <h2>Creating an Estimator - Multi-Instance Training,</h2>

# %%
###in this cell, create and fit an estimator using multi-instance training
multi_instance_estimator = PyTorch(
    entry_point='hpo.py',
    base_job_name='dog-pytorch',
    role=role,
    instance_count=3,
    instance_type='ml.m5.2xlarge',
    framework_version='1.4.0',
    py_version='py3',
    hyperparameters=hyperparameters,
    ## Debugger and Profiler parameters
    rules = rules,
    debugger_hook_config=hook_config,
    profiler_config=profiler_config,
)
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
multi_instance_estimator.fit({"training": "s3://udacitymlproject4/"}, wait=True)
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: dog-pytorch-2023-04-17-11-29-15-852
# 2023-04-17 11:29:16 Starting - Starting the training job...
# 2023-04-17 11:29:41 Starting - Preparing the instances for trainingVanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# PoorWeightInitialization: InProgress
# ProfilerReport: InProgress
# ......
# 2023-04-17 11:30:41 Downloading - Downloading input data......
# 2023-04-17 11:31:41 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-04-17 11:31:43,589 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-04-17 11:31:43,593 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:43,604 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-04-17 11:31:43,606 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-04-17 11:31:43,779 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2023-04-17 11:31:43,779 sagemaker-containers INFO     Generating setup.cfg
# 2023-04-17 11:31:43,779 sagemaker-containers INFO     Generating MANIFEST.in
# 2023-04-17 11:31:43,779 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# Processing /tmp/tmptveu3wp7/module_dir
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-04-17 11:31:44,466 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-04-17 11:31:44,469 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:44,480 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-04-17 11:31:44,482 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-04-17 11:31:44,629 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2023-04-17 11:31:44,630 sagemaker-containers INFO     Generating setup.cfg
# 2023-04-17 11:31:44,630 sagemaker-containers INFO     Generating MANIFEST.in
# 2023-04-17 11:31:44,630 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-04-17 11:31:44,113 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-04-17 11:31:44,116 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:44,127 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-04-17 11:31:44,129 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-04-17 11:31:44,284 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2023-04-17 11:31:44,284 sagemaker-containers INFO     Generating setup.cfg
# 2023-04-17 11:31:44,284 sagemaker-containers INFO     Generating MANIFEST.in
# 2023-04-17 11:31:44,284 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# Processing /tmp/tmpj828wwcb/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6321 sha256=ed159efba2c816367e178d9a33aa9d375234bc323868d1f9f9352f6c86f25927
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ou_hgk2g/wheels/26/c3/7c/2add403f00761630ff0d00bc73c170486dc571314176aee426
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# Processing /tmp/tmp2h3o7_41/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6321 sha256=9641363962dd0940652341282b778ce082141edfeb73cef1cf102891312f6bdf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tc9fglgm/wheels/7c/47/c7/bd43f64e08807b2a671faa0867c3a5ad531961c14bc3a81518
# Successfully built default-user-module-name
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6321 sha256=9641363962dd0940652341282b778ce082141edfeb73cef1cf102891312f6bdf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jc23i7p6/wheels/c2/05/86/65124eff5ca6e07f64e1bb862c7a0768c1cb59b1e18cf2b7d4
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2023-04-17 11:31:45,763 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:45,778 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:45,790 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:45,800 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3"
#     ],
#     "hyperparameters": {
#         "batch_size": 128,
#         "learning_rate": "0.00662117582001255"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "dog-pytorch-2023-04-17-11-29-15-852",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz",
#     "module_name": "hpo",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2",
#                     "algo-3"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "hpo.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"learning_rate":"0.00662117582001255"}
# SM_USER_ENTRY_POINT=hpo.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1","algo-2","algo-3"],"instance_groups":[{"hosts":["algo-1","algo-2","algo-3"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=hpo
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3"],"hyperparameters":{"batch_size":128,"learning_rate":"0.00662117582001255"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"dog-pytorch-2023-04-17-11-29-15-852","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz","module_name":"hpo","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1","algo-2","algo-3"],"instance_groups":[{"hosts":["algo-1","algo-2","algo-3"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"hpo.py"}
# SM_USER_ARGS=["--batch_size","128","--learning_rate","0.00662117582001255"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=128
# SM_HP_LEARNING_RATE=0.00662117582001255
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 hpo.py --batch_size 128 --learning_rate 0.00662117582001255
# Namespace(batch_size=128, data='/opt/ml/input/data/training', learning_rate=0.00662117582001255, model_dir='/opt/ml/model', output_dir='/opt/ml/output/data')
# Hyperparameters are LR: 0.00662117582001255, Batch Size: 128
# Data Paths: /opt/ml/input/data/training
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2023-04-17 11:31:46,511 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:46,524 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:46,537 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:46,546 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3"
#     ],
#     "hyperparameters": {
#         "batch_size": 128,
#         "learning_rate": "0.00662117582001255"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "dog-pytorch-2023-04-17-11-29-15-852",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz",
#     "module_name": "hpo",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "current_instance_type": "ml.m5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2",
#                     "algo-3"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "hpo.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"learning_rate":"0.00662117582001255"}
# SM_USER_ENTRY_POINT=hpo.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1","algo-2","algo-3"],"instance_groups":[{"hosts":["algo-1","algo-2","algo-3"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=hpo
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3"],"hyperparameters":{"batch_size":128,"learning_rate":"0.00662117582001255"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"dog-pytorch-2023-04-17-11-29-15-852","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz","module_name":"hpo","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1","algo-2","algo-3"],"instance_groups":[{"hosts":["algo-1","algo-2","algo-3"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"hpo.py"}
# SM_USER_ARGS=["--batch_size","128","--learning_rate","0.00662117582001255"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=128
# SM_HP_LEARNING_RATE=0.00662117582001255
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 hpo.py --batch_size 128 --learning_rate 0.00662117582001255
# 2023-04-17 11:31:46,201 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:46,214 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:46,227 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-17 11:31:46,237 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-3",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3"
#     ],
#     "hyperparameters": {
#         "batch_size": 128,
#         "learning_rate": "0.00662117582001255"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "dog-pytorch-2023-04-17-11-29-15-852",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz",
#     "module_name": "hpo",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-3",
#         "current_instance_type": "ml.m5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2",
#                     "algo-3"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "hpo.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"learning_rate":"0.00662117582001255"}
# SM_USER_ENTRY_POINT=hpo.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-3","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1","algo-2","algo-3"],"instance_groups":[{"hosts":["algo-1","algo-2","algo-3"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-3
# SM_MODULE_NAME=hpo
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-3","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3"],"hyperparameters":{"batch_size":128,"learning_rate":"0.00662117582001255"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"dog-pytorch-2023-04-17-11-29-15-852","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-075730753027/dog-pytorch-2023-04-17-11-29-15-852/source/sourcedir.tar.gz","module_name":"hpo","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-3","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1","algo-2","algo-3"],"instance_groups":[{"hosts":["algo-1","algo-2","algo-3"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"hpo.py"}
# SM_USER_ARGS=["--batch_size","128","--learning_rate","0.00662117582001255"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=128
# SM_HP_LEARNING_RATE=0.00662117582001255
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 hpo.py --batch_size 128 --learning_rate 0.00662117582001255
# Namespace(batch_size=128, data='/opt/ml/input/data/training', learning_rate=0.00662117582001255, model_dir='/opt/ml/model', output_dir='/opt/ml/output/data')
# Hyperparameters are LR: 0.00662117582001255, Batch Size: 128
# Data Paths: /opt/ml/input/data/training
# Starting Model Training
# Epoch: 0
# Namespace(batch_size=128, data='/opt/ml/input/data/training', learning_rate=0.00662117582001255, model_dir='/opt/ml/model', output_dir='/opt/ml/output/data')
# Hyperparameters are LR: 0.00662117582001255, Batch Size: 128
# Data Paths: /opt/ml/input/data/training
# Starting Model Training
# Epoch: 0
# Starting Model Training
# Epoch: 0
# [2023-04-17 11:31:48.742 algo-1:50 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-17 11:31:48.742 algo-1:50 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-17 11:31:48.742 algo-1:50 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2023-04-17 11:31:48.743 algo-1:50 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-04-17 11:31:48.745 algo-1:50 INFO hook.py:382] Monitoring the collections: relu_input, losses, gradients
# [2023-04-17 11:31:48.745 algo-1:50 INFO hook.py:443] Hook is writing from the hook with pid: 50
# [2023-04-17 11:31:49.651 algo-2:50 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-17 11:31:49.652 algo-2:50 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-17 11:31:49.652 algo-2:50 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2023-04-17 11:31:49.652 algo-2:50 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-04-17 11:31:49.654 algo-2:50 INFO hook.py:382] Monitoring the collections: gradients, relu_input, losses
# [2023-04-17 11:31:49.654 algo-2:50 INFO hook.py:443] Hook is writing from the hook with pid: 50
# [2023-04-17 11:31:49.316 algo-3:50 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-17 11:31:49.316 algo-3:50 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-17 11:31:49.317 algo-3:50 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2023-04-17 11:31:49.317 algo-3:50 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-04-17 11:31:49.318 algo-3:50 INFO hook.py:382] Monitoring the collections: losses, relu_input, gradients
# [2023-04-17 11:31:49.319 algo-3:50 INFO hook.py:443] Hook is writing from the hook with pid: 50
# train loss: 436.0000, acc: 27.0000, best loss: 1000000.0000
# train loss: 485.0000, acc: 20.0000, best loss: 1000000.0000
# train loss: 521.0000, acc: 12.0000, best loss: 1000000.0000
# valid loss: 184.0000, acc: 65.0000, best loss: 184.0000
# Testing Model
# valid loss: 227.0000, acc: 55.0000, best loss: 227.0000
# Testing Model
# valid loss: 319.0000, acc: 34.0000, best loss: 319.0000
# Testing Model
# Testing Loss: 189.0
# Testing Accuracy: 60.0
# Saving Model
# 2023-04-17 11:42:40,014 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Testing Loss: 232.0
# Testing Accuracy: 52.0
# Saving Model
# 2023-04-17 11:42:42,279 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Testing Loss: 324.0
# Testing Accuracy: 33.0
# Saving Model
# 2023-04-17 11:42:47,853 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# VanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# PoorWeightInitialization: IssuesFound
#
# 2023-04-17 11:43:43 Uploading - Uploading generated training model
# 2023-04-17 11:44:15 Completed - Training job completed
# Training seconds: 2496
# Billable seconds: 2496

# %% [markdown]
# <h2>Deployment</h2>

# %%
model_location=best_estimator.model_data

# %%
import sagemaker
import boto3
from sagemaker.tuner import CategoricalParameter, ContinuousParameter, HyperparameterTuner
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role
from sagemaker.debugger import Rule, DebuggerHookConfig, TensorBoardOutputConfig, CollectionConfig, ProfilerRule, rule_configs
from sagemaker.debugger import ProfilerConfig, FrameworkProfile

from sagemaker.pytorch import PyTorchModel
from sagemaker.predictor import Predictor

# %%
jpeg_serializer = sagemaker.serializers.IdentitySerializer("image/jpeg")
json_deserializer = sagemaker.deserializers.JSONDeserializer()


class ImagePredictor(Predictor):
    def __init__(self, endpoint_name, sagemaker_session):
        super(ImagePredictor, self).__init__(
            endpoint_name,
            sagemaker_session=sagemaker_session,
            serializer=jpeg_serializer,
            deserializer=json_deserializer,
        )

# %%
role = sagemaker.get_execution_role()

# %%
pytorch_model = PyTorchModel(model_data=model_location, role=role, entry_point='infernce2.py',py_version='py3',
                             framework_version='1.4',
                             predictor_cls=ImagePredictor)

# %%
predictor = pytorch_model.deploy(initial_instance_count=3, instance_type='ml.m5.2xlarge')
# Out:
# ----!

# %%
import requests
#request_dict={ "url": "https://cdn1-www.cattime.com/assets/uploads/2011/12/file_2744_british-shorthair-460x290-460x290.jpg" }
request_dict={ "url": "https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/20113314/Carolina-Dog-standing-outdoors.jpg" }

img_bytes = requests.get(request_dict['url']).content
type(img_bytes)
# Out:
# bytes

# %%
from PIL import Image
import io
Image.open(io.BytesIO(img_bytes))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=729x486>

# %%
response=predictor.predict(img_bytes, initial_args={"ContentType": "image/jpeg"})

# %%
import json
response2=predictor.predict(json.dumps(request_dict), initial_args={"ContentType": "application/json"})

# %%
type(response2[0][0])
# Out:
# float

# %%
response2[0]
# Out:
# [-7.380711555480957,
#  -2.193012237548828,
#  -1.728313684463501,
#  1.0639053583145142,
#  -5.764138698577881,
#  -2.0543229579925537,
#  -0.11336326599121094,
#  -2.4461753368377686,
#  -6.334575176239014,
#  -0.059182897210121155,
#  2.2222537994384766,
#  -5.8622870445251465,
#  -1.5888727903366089,
#  3.4883241653442383,
#  -6.742661952972412,
#  -3.5655410289764404,
#  -7.756707191467285,
#  0.51579350233078,
#  -2.596541166305542,
#  0.624711275100708,
#  -5.459048748016357,
#  -1.4667305946350098,
#  -8.425110816955566,
#  -2.6374971866607666,
#  -2.1247544288635254,
#  -7.312129974365234,
#  -4.063277244567871,
#  -4.881282329559326,
#  -9.135810852050781,
#  -1.979447841644287,
#  -3.402405261993408,
#  -1.6739455461502075,
#  -6.237095355987549,
#  -1.9730955362319946,
#  -7.204339027404785,
#  -4.231589317321777,
#  -3.3783626556396484,
#  -2.825732946395874,
#  0.9898806214332581,
#  -3.4377262592315674,
#  -4.417032241821289,
#  -3.827392339706421,
#  4.0011773109436035,
#  -4.73421573638916,
#  -0.1472233235836029,
#  -7.304174423217773,
#  -2.9438207149505615,
#  0.9557904005050659,
#  -1.003993034362793,
#  -1.9377481937408447,
#  -0.7455170154571533,
#  -7.2911481857299805,
#  -6.130460739135742,
#  -4.729010105133057,
#  -6.329882621765137,
#  0.7456550598144531,
#  -4.622544288635254,
#  -5.933962345123291,
#  -1.715885877609253,
#  -2.245922803878784,
#  -5.296690464019775,
#  -6.6070404052734375,
#  -6.756529808044434,
#  -6.451450347900391,
#  -5.082509517669678,
#  -7.02907133102417,
#  2.6871604919433594,
#  -7.149559020996094,
#  -0.8146885633468628,
#  2.15674090385437,
#  0.4032323658466339,
#  -3.453300952911377,
#  -4.5782999992370605,
#  -3.7120320796966553,
#  -6.98536491394043,
#  -2.392547607421875,
#  -5.4635515213012695,
#  -3.8636937141418457,
#  -7.765507698059082,
#  -6.9465651512146,
#  -0.0006056942511349916,
#  -5.615757465362549,
#  2.129861354827881,
#  -0.9954796433448792,
#  -5.044827938079834,
#  -1.2337369918823242,
#  1.02753746509552,
#  -4.728263854980469,
#  -5.745983600616455,
#  1.007347822189331,
#  -6.506649494171143,
#  -7.23537540435791,
#  -2.519806385040283,
#  -3.383526086807251,
#  -5.904411315917969,
#  -2.7918989658355713,
#  -0.888136088848114,
#  -3.530907154083252,
#  -5.03824520111084,
#  -5.818111419677734,
#  -4.705559253692627,
#  -0.7301701903343201,
#  -2.5674099922180176,
#  -3.0622081756591797,
#  -5.659763813018799,
#  -7.212954044342041,
#  -4.400479316711426,
#  -0.8135374784469604,
#  -1.935096263885498,
#  -0.6939371824264526,
#  -1.514161467552185,
#  -2.537799119949341,
#  -5.177409648895264,
#  -5.3789238929748535,
#  -3.0731167793273926,
#  -0.04173412173986435,
#  -5.255262851715088,
#  -0.6200686097145081,
#  -9.878876686096191,
#  1.9771283864974976,
#  -2.162306785583496,
#  -1.4170366525650024,
#  -3.3832664489746094,
#  -0.6277105212211609,
#  -7.250619888305664,
#  -7.221494197845459,
#  -0.4180922210216522,
#  1.3708810806274414,
#  -7.798966884613037,
#  -3.505674362182617,
#  -5.239019870758057,
#  0.06558484584093094,
#  -3.107116222381592]

# %%
import torch
import numpy as np
np.argmax(response, 1)
# Out:
# array([42])
